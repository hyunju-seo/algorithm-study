# %% [markdown]
# ##내 풀이

# %%
tup=("SUN","MON", "TUE", "WED", "THU", "FRI", "SAT")
date={1:31, 3:31, 5:31, 7:31, 8:31, 10:31, 12:31, 4:30, 6:30, 9:30, 11:30,2:28}
month, day=map(int, input().split())
sum=day
for i in range(month-1):
  sum+=date[i+1]
sum=result%7
print(tup[sum])
# Out:
# 12 31
# MON

# %% [markdown]
# ##다른사람 풀이

# %%
from calendar import weekday
l=['MON','TUE','WED','THU','FRI','SAT','SUN']
d = weekday(2007,*map(int,input().split()))
print(l[d])
# Out:
# 1 1
# MON

# %% [markdown]
# **calendar.weekday(year, month, day)**
#
# year (1970--...), month (1--12), day (1--31)의 요일(0은 월요일)을 반환합니다.
